# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
from pymongo import MongoClient
import pandas as pd
client = MongoClient()
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# Siguiendo estos pasos me da error al intentar insertar el documento en Mongo, lo dejo escrito (y por eso no lo ejecuto),
# pero lo que he hecho al final ha sido crear la database e insertar el documento desde el propio Mongo.

import pandas as pd
pd.options.display.max_columns = None
df = pd.read_json("companies.json", lines = True)
mydb = client["empresas"]
coleccion = mydb.detalles
coleccion.insert_many(df.to_dict("records"))

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'empresas2', 'local']

# %%
db = client["empresas2"]
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'empresas2')

# %%
coleccion = db.detalles
coleccion
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'empresas2'), 'detalles')

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
list(coleccion.find({"name":"Babelgum"}, {"name":1,"_id":0}))[0]
# Out:
# {'name': 'Babelgum'}

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
list(coleccion.find({'number_of_employees': {"$gt": 5000}}).limit(20).sort("number_of_employees", 1))[0]
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297e49'),
#  'name': 'Nintendo',
#  'permalink': 'nintendo',
#  'crunchbase_url': 'http://www.crunchbase.com/company/nintendo',
#  'homepage_url': 'http://nintendo.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'NintendoAmerica',
#  'category_code': 'games_video',
#  'number_of_employees': 5080,
#  'founded_year': 1889,
#  'founded_month': 9,
#  'founded_day': 23,
#  'deadpooled_year': None,
#  'deadpooled_month': None,
#  'deadpooled_day': None,
#  'deadpooled_url': None,
#  'tag_list': 'games, console',
#  'alias_list': '',
#  'email_address': 'noalegal@noa.nintendo.com',
#  'phone_number': '1-800-255-3700 ',
#  'description': '',
#  'created_at': 'Sat Dec 22 13:27:00 UTC 2007',
#  'updated_at': 'Thu Sep 05 12:41:16 UTC 2013',
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005]

list(coleccion.find({"founded_year": {"$in": years}}, {"name":1, "founded_year":1, "_id":0}))[:3]
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004}]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond1 = {"ipo.valuation_amount": {"$gt": 100000000}}
cond2 = {"founded_year": {"$lt": 2010}}

list(coleccion.find({'$and': [cond1, cond2]}, {"name":1,"ipo":1,"_id":0}))[:2]
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}}]

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond1 = {"number_of_employees": {"$lt": 1000}}
cond2 = {"founded_year": {"$lt": 2005}}

list(coleccion.find({'$and': [cond1, cond2]}).sort("number_of_employees", -1).limit(10))[0]
# Out:
# {'_id': ObjectId('52cdef7d4bab8bd675298933'),
#  'name': 'Infinera Corporation',
#  'permalink': 'infinera',
#  'crunchbase_url': 'http://www.crunchbase.com/company/infinera',
#  'homepage_url': 'http://www.infinera.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'InfineraCorp',
#  'category_code': 'network_hosting',
#  'number_of_employees': 974,
#  'founded_year': 2000,
#  'founded_month': None,
#  'founded_day': None,
#  'deadpooled_year': None,
#  'deadpooled_month': None,
#  'deadpooled_day': None,
#  'deadpooled_url': None,
#  'tag_list': None,
#  'alias_list': 'Zepton Networks',
#  'email_address': '',
#  'phone_number': '408-572-5200',
#  'description': 'Optical Networking Systems',
#  'created_at': 'Tue Apr 29 19:43:09 UTC 2008',
#  'updated_at': 'Tue Jan 10 22:07:21 UTC 2012',
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(coleccion.find({'partners': {'$exists': False}}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(coleccion.find({"category_code": {"$type": "null"}}, {"_id":0, "name":1}))[:5]
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'}]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond1 = {"number_of_employees": {"$gte": 100}}
cond2 = {"number_of_employees": {"$lt": 1000}}

list(coleccion.find({'$and': [cond1, cond2]}, {"name":1,"number_of_employees":1,"_id":0}))[:3]
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'OpenX', 'number_of_employees': 305}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
list(coleccion.find().sort("ipo", -1))[0]
# Out:
# {'_id': ObjectId('52cdef7e4bab8bd67529a8b4'),
#  'name': 'GREE',
#  'permalink': 'gree',
#  'crunchbase_url': 'http://www.crunchbase.com/company/gree',
#  'homepage_url': 'http://www.gree-corp.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'gree_corp',
#  'category_code': 'games_video',
#  'number_of_employees': 700,
#  'founded_year': 2004,
#  'founded_month': 12,
#  'founded_day': 7,
#  'deadpooled_year': None,
#  'deadpooled_month': None,
#  'deadpooled_day': None,
#  'deadpooled_url': None,
#  'tag_list': 'mobile-web, japan, tokyo, social-network, mobile-social-network, mobile-games',
#  'alias_list': None,
#  'email_address': 'inquiry@gree-corp.com',
#  'phone_number': '',
#  'description': 'Internet media business,SNS,  free game',
#  'created_at': 'Sat Dec 20 16:42:57 UTC 2008',
#  'updated_at': 'Tue Jan 01 21:37:04 UTC 2013',
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
list(coleccion.find({'number_of_employees': {"$gt": 1}}).sort("number_of_employees", -1).limit(10))[:3]
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd67529941a'),
#   'name': 'Siemens',
#   'permalink': 'siemens',
#   'crunchbase_url': 'http://www.crunchbase.com/company/siemens',
#   'homepage_url': 'http://www.siemens.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'Siemens',
#   'category_code': 'hardware',
#   'number_of_employees': 405000,
#   'founded_year': 1847,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'automation, building-technologies, drive-technology, energy',
#   'alias_list': '',
#   'email_address': 'contact@siemens.com',
#   'phone_number': '49 89 636 34134',
#   'description': 'Electronics and Electrical Engineering',
#   'created_at': 'Thu Jul 31 09:29:43 UTC 2008',
#   'updated_at': 'Thu Nov 28 20:32:55 UTC 2013',
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(coleccion.find({'founded_month': {"$gt": 6}}).limit(1000))[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'permalink': 'abc2',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#   'homepage_url': 'http://wetpaint-inc.com',
#   'blog_url': 'http://digitalquarters.net/',
#   'blog_feed_url': 'http://digitalquarters.net/feed/',
#   'twitter_username': 'BachelrWetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'founded_month': 10,
#   'founded_day': 17,
#   'deadpooled_year': 1,
#   'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#   'alias_list': '',
#   'email_address': 'info@wetpaint.com',
#   'phone_number': '206.859.6300',
#   'description': 'Technology Platform Company',
#   'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#   'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
# ...

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
cond1 = {"founded_year": {"$lt": 2000}}
cond2 = {"acquisition.price_amount": {"$gt": 100000}}

list(coleccion.find({'$and': [cond1, cond2]}))[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d90'),
#   'name': 'Postini',
#   'permalink': 'postini',
#   'crunchbase_url': 'http://www.crunchbase.com/company/postini',
#   'homepage_url': 'http://postini.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': None,
#   'category_code': 'web',
#   'number_of_employees': None,
#   'founded_year': 1999,
#   'founded_month': 6,
#   'founded_day': 2,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': None,
#   'email_address': '',
#   'phone_number': '888.584.3150',
#   'description': None,
#   'created_at': 'Fri Jun 08 12:19:51 UTC 2007',
#   'updated_at': 'Sat Aug 13 18:02:34 UTC 2011',
# ...

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
list(coleccion.find({'acquisition.acquired_year': {"$gt": 2010}}, {"name":1,"acquisition":1,"_id":0}).sort("acquisition.price_amount", -1))[:3]
# Out:
# [{'name': 'T-Mobile',
#   'acquisition': {'price_amount': 39000000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/03/20/in-the-race-for-more-spectrum-att-is-acquiring-t-mobile-for-39-billion/',
#    'source_description': 'In The Race For More Spectrum, AT&T Is Acquiring T-Mobile For $39 Billion',
#    'acquired_year': 2011,
#    'acquired_month': 3,
#    'acquired_day': 20,
#    'acquiring_company': {'name': 'AT&T', 'permalink': 'at-t'}}},
#  {'name': 'Goodrich Corporation',
#   'acquisition': {'price_amount': 18400000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://www.masshightech.com/stories/2011/09/19/daily37-UTC-shells-out-184-billion-for-Goodrich.html',
#    'source_description': 'UTC shells out $18.4 billion for Goodrich',
#    'acquired_year': 2011,
#    'acquired_month': 9,
#    'acquired_day': 22,
#    'acquiring_company': {'name': 'United Technologies',
# ...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(coleccion.find({}, {"name":1,"founded_year":1,"_id":0}).sort("founded_year", -1))[:5]
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013}]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
list(coleccion.find({'founded_day': {"$gte": 17}}).sort("acquisition.price_amount", -1).limit(10))[:1]
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd675298934'),
#   'name': 'Siebel Systems',
#   'permalink': 'siebel',
#   'crunchbase_url': 'http://www.crunchbase.com/company/siebel',
#   'homepage_url': 'http://www.siebel.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': '',
#   'category_code': 'software',
#   'number_of_employees': None,
#   'founded_year': 1993,
#   'founded_month': 1,
#   'founded_day': 30,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'crm',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '',
#   'description': '',
#   'created_at': 'Tue Apr 29 19:51:51 UTC 2008',
#   'updated_at': 'Wed Jan 04 08:07:44 UTC 2012',
#   'overview': '<p>Siebel Systems was a CRM software company bought by <a href="http://www.crunchbase.com/company/oracle" title="Oracle">Oracle</a> in January 2006.</p>',
#   'image': {'available_sizes': [[[150, 45],
# ...

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
cond1 = {"category_code": "web"}
cond2 = {"number_of_employees": {"$gt": 4000}}

list(coleccion.find({'$and': [cond1, cond2]}).sort("number_of_employees", 1))[0]
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd67529822a'),
#  'name': 'Expedia',
#  'permalink': 'expedia',
#  'crunchbase_url': 'http://www.crunchbase.com/company/expedia',
#  'homepage_url': 'http://www.expedia.com',
#  'blog_url': '',
#  'blog_feed_url': '',
#  'twitter_username': 'Expedia',
#  'category_code': 'web',
#  'number_of_employees': 4400,
#  'founded_year': 1996,
#  'founded_month': None,
#  'founded_day': None,
#  'deadpooled_year': None,
#  'deadpooled_month': None,
#  'deadpooled_day': None,
#  'deadpooled_url': None,
#  'tag_list': 'travel, flights, hotels, tickets, airline, vacation, travel-comparison, travel-search',
#  'alias_list': '',
#  'email_address': '',
#  'phone_number': '1-800-EXPEDIA',
#  'description': '',
#  'created_at': 'Sun Feb 10 03:29:12 UTC 2008',
#  'updated_at': 'Sun Dec 08 07:03:33 UTC 2013',
# ...

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond1 = {"acquisition.price_amount": {"$gt": 10000000}}
cond2 = {"acquisition.price_currency_code": "EUR"}

list(coleccion.find({'$and': [cond1, cond2]}))[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297f02'),
#   'name': 'ZYB',
#   'permalink': 'zyb',
#   'crunchbase_url': 'http://www.crunchbase.com/company/zyb',
#   'homepage_url': 'http://zyb.com',
#   'blog_url': 'http://blog.zyb.com/',
#   'blog_feed_url': 'http://blog.zyb.com/index.php/feed/',
#   'twitter_username': None,
#   'category_code': 'mobile',
#   'number_of_employees': 25,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'mobile, social-networking, socialnetwork',
#   'alias_list': '',
#   'email_address': 'contact@zyb.com',
#   'phone_number': '',
#   'description': 'Mobile Social Networking',
#   'created_at': 'Wed Aug 22 05:14:51 UTC 2007',
#   'updated_at': 'Tue Jul 02 03:00:50 UTC 2013',
# ...

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(coleccion.find({'acquisition.acquired_month': {"$lt": 4}}, {"name":1,"acquisition":1,"_id":0}).limit(10))[:2]
# Out:
# [{'name': 'Kyte',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/',
#    'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million',
#    'acquired_year': 2011,
#    'acquired_month': 1,
#    'acquired_day': 31,
#    'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}},
#  {'name': 'NetRatings',
#   'acquisition': {'price_amount': 327000000,
#    'price_currency_code': 'USD',
#    'term_code': 'cash',
#    'source_url': 'http://login.vnuemedia.com/hr/login/login_subscribe.jsp?id=0oqDem1gYIfIclz9i2%2Ffqj5NxCp2AC5DPbVnyT2da8GyV2mXjasabE128n69OrmcAh52%2FGE3pSG%2F%0AEKRYD9vh9EhrJrxukmUzh532fSMTZXL42gwPB80UWVtF1NwJ5UZSM%2BCkLU1mpYBoHFgiH%2Fi0f6Ax%0A9yMIVxt47t%2BHamhEQ0nkOEK24L',
#    'source_description': 'Nielsen buys rest of NetRatings',
# ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
cond1 = {"founded_year": {"$in": years}}
cond2 = {"acquisition.acquired_year": {"$gt": 2011}}

list(coleccion.find({'$and': [cond1, cond2]}))[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'permalink': 'abc2',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#   'homepage_url': 'http://wetpaint-inc.com',
#   'blog_url': 'http://digitalquarters.net/',
#   'blog_feed_url': 'http://digitalquarters.net/feed/',
#   'twitter_username': 'BachelrWetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'founded_month': 10,
#   'founded_day': 17,
#   'deadpooled_year': 1,
#   'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#   'alias_list': '',
#   'email_address': 'info@wetpaint.com',
#   'phone_number': '206.859.6300',
#   'description': 'Technology Platform Company',
#   'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#   'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
# ...

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.
