# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://localhost:27017")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_json("..\companies.json", lines=True)

# %%
df.head(1)
# Out:
#                                     _id      name permalink  \
# 0  {'$oid': '52cdef7c4bab8bd675297d8a'}  Wetpaint      abc2
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0  BachelrWetpaint           web                 47.0        2005.0
#
#    founded_month  founded_day  deadpooled_year  \
# 0           10.0         17.0              1.0
#
#                                             tag_list alias_list  \
# 0  wiki, seattle, elowitz, media-industry, media-...
#
#        email_address  phone_number                  description  \
# 0  info@wetpaint.com  206.859.6300  Technology Platform Company
#
#                  created_at                updated_at  \
# ...

# %%
mydb = client["companies_data"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies_data')

# %%
coleccion = mydb.c_data
coleccion
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies_data'), 'c_data')

# %%
#ERROR!: CREADA BBDD DESDE MONGO, DÓNDE ESTÁ EL PROBLEMA?
#coleccion.insert_many(df.to_dict("records"))

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
list(coleccion.find({"name": {"$eq": "Babelgum"}}, {"etiqueta":1,"_id":0,"name":1}))[0:5]
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
emp = pd.DataFrame(coleccion.find({'number_of_employees': {"$gt": 5000}}).limit(20).sort("number_of_employees", -1)) 
emp.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7d4bab8bd67529941a  Siemens   siemens
# 1  52cdef7c4bab8bd67529856a      IBM       ibm
#
#                               crunchbase_url            homepage_url blog_url  \
# 0  http://www.crunchbase.com/company/siemens  http://www.siemens.com
# 1      http://www.crunchbase.com/company/ibm      http://www.ibm.com
#
#   blog_feed_url twitter_username category_code  number_of_employees  \
# 0                        Siemens      hardware               405000
# 1                            IBM      software               388000
#
#    founded_year  founded_month  founded_day deadpooled_year deadpooled_month  \
# 0        1847.0            NaN          NaN            None             None
# 1        1896.0            NaN          NaN            None             None
#
#   deadpooled_day deadpooled_url  \
# 0           None           None
# 1           None
#
#                                             tag_list alias_list  \
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
cond1 = {'founded_year': {"$gte": 2000}}
cond2 = {'founded_year': {"$lte": 2005}}

list(coleccion.find({'$and': [cond1, cond2]}, {"etiqueta":1,"_id":0,"name":1,"founded_year":1}))[0:5]
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005}]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond1 = {'founded_year': {"$lt": 2010}}
cond2 = {'ipo.valuation_amount': {"$gt": 100000000}}

list(coleccion.find({'$and': [cond1, cond2]}, {"etiqueta":1,"_id":0,"name":1,"ipo":1}))[0:2]
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}}]

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond1 = {'founded_year': {"$lt": 2005}}
cond2 = {'number_of_employees': {"$lt": 1000}}

empf = pd.DataFrame(coleccion.find({'$and': [cond1, cond2]}).limit(10).sort("number_of_employees", -1))
empf.head(2)
# Out:
#                         _id                             name  \
# 0  52cdef7d4bab8bd675298933             Infinera Corporation
# 1  52cdef7e4bab8bd67529ac95  NorthPoint Communications Group
#
#                          permalink  \
# 0                         infinera
# 1  northpoint-communications-group
#
#                                       crunchbase_url             homepage_url  \
# 0         http://www.crunchbase.com/company/infinera  http://www.infinera.com
# 1  http://www.crunchbase.com/company/northpoint-c...
#
#   blog_url blog_feed_url twitter_username    category_code  \
# 0                            InfineraCorp  network_hosting
# 1                                          network_hosting
#
#    number_of_employees  founded_year  founded_month  founded_day  \
# 0                  974          2000            NaN          NaN
# 1                  948          1997            NaN          NaN
#
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
partf = pd.DataFrame(coleccion.find({"partners": {"$exists": False}}))
partf.head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
ntp = pd.DataFrame(coleccion.find({"category_code": {"$type": "null"}}))
ntp.head(5)
# Out:
#                         _id          name     permalink  \
# 0  52cdef7c4bab8bd6752980f6    Collective    collective
# 1  52cdef7c4bab8bd675298225       Snimmer       snimmer
# 2  52cdef7c4bab8bd675298226        KoolIM        koolim
# 3  52cdef7c4bab8bd675298261  Level9 Media  level9-media
# 4  52cdef7c4bab8bd675298262       VidKing       vidking
#
#                                    crunchbase_url            homepage_url  \
# 0    http://www.crunchbase.com/company/collective                    None
# 1       http://www.crunchbase.com/company/snimmer                    None
# 2        http://www.crunchbase.com/company/koolim                    None
# 3  http://www.crunchbase.com/company/level9-media                    None
# 4       http://www.crunchbase.com/company/vidking  http://www.VidKing.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0     None          None             None          None                  NaN
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond1 = {'number_of_employees': {"$gte": 100}}
cond2 = {'number_of_employees': {"$lt": 1000}}

list(coleccion.find({'$and': [cond1, cond2]}, {"etiqueta":1,"_id":0,"name":1,"number_of_employees":1}))[0:5]
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'OpenX', 'number_of_employees': 305},
#  {'name': 'LifeLock', 'number_of_employees': 644},
#  {'name': 'Jajah', 'number_of_employees': 110}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
IPO = pd.DataFrame(coleccion.find().sort("ipo.price", -1))
IPO.head(1)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint      abc2
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0  BachelrWetpaint           web                 47.0        2005.0
#
#    founded_month  founded_day  deadpooled_year  \
# 0           10.0         17.0              1.0
#
#                                             tag_list alias_list  \
# 0  wiki, seattle, elowitz, media-industry, media-...
#
#        email_address  phone_number                  description  \
# 0  info@wetpaint.com  206.859.6300  Technology Platform Company
#
#             created_at                    updated_at  \
# ...

# %%
ip = pd.DataFrame(coleccion.find({"ipo.price": {"$exists": True}}))
ip.head(1)

#IPO price no existe??
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list(coleccion.find({'ipo.price': {"$exists": True}},{"etiqueta":1,"_id":0,"name":1}).sort("ipo.price", -1))[0:10]
# Out:
# []

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
top10 = pd.DataFrame(coleccion.find().limit(10).sort("number_of_employees", -1))
top10
# Out:
#                         _id                                        name  \
# 0  52cdef7d4bab8bd67529941a                                     Siemens
# 1  52cdef7c4bab8bd67529856a                                         IBM
# 2  52cdef7d4bab8bd675299d33                                      Toyota
# 3  52cdef7c4bab8bd675297e89                                      PayPal
# 4  52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5  52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6  52cdef7d4bab8bd675298b99                                   Accenture
# 7  52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8  52cdef7e4bab8bd67529aa51                   Flextronics International
# 9  52cdef7d4bab8bd675299156                                     Safeway
#
#                                     permalink  \
# 0                                     siemens
# 1                                         ibm
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
secsem = pd.DataFrame(coleccion.find({'founded_month': {"$gt": 6}}).limit(1000)) 
secsem.head(2)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8c      Zoho      abc4
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1      http://www.crunchbase.com/company/zoho          http://zoho.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1       http://blogs.zoho.com/        http://blogs.zoho.com/feed
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0  BachelrWetpaint           web                 47.0          2005
# 1             zoho      software               1600.0          2005
#
#    founded_month  founded_day  deadpooled_year  \
# 0             10         17.0              1.0
# 1              9         15.0              3.0
#
# ...

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
cond1 = {'founded_year': {"$lt": 2000}}
cond2 = {'acquisition.price_amount': {"$gt": 1000000}}

adq = pd.DataFrame(coleccion.find({'$and': [cond1, cond2]}))
adq.head(2)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d90   Postini   postini
# 1  52cdef7c4bab8bd675297deb  SideStep  sidestep
#
#                                crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/postini       http://postini.com
# 1  http://www.crunchbase.com/company/sidestep  http://www.sidestep.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0                                    None           web                  NaN
# 1     None          None             None           web                 75.0
#
#    founded_year  founded_month  founded_day  deadpooled_year  \
# 0          1999            6.0          2.0              NaN
# 1          1999           11.0          1.0              NaN
#
#    deadpooled_month  deadpooled_day deadpooled_url  \
# 0               NaN             NaN           None
# 1               NaN             NaN           None
#
# ...

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
list(coleccion.find({'acquisition.acquired_year': {"$gt": 2010}},{"etiqueta":1,"_id":0,"name":1,"acquisition":1}).sort("acquisition.price_amount", -1))[0:2]
# Out:
# [{'name': 'T-Mobile',
#   'acquisition': {'price_amount': 39000000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/03/20/in-the-race-for-more-spectrum-att-is-acquiring-t-mobile-for-39-billion/',
#    'source_description': 'In The Race For More Spectrum, AT&T Is Acquiring T-Mobile For $39 Billion',
#    'acquired_year': 2011,
#    'acquired_month': 3,
#    'acquired_day': 20,
#    'acquiring_company': {'name': 'AT&T', 'permalink': 'at-t'}}},
#  {'name': 'Goodrich Corporation',
#   'acquisition': {'price_amount': 18400000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://www.masshightech.com/stories/2011/09/19/daily37-UTC-shells-out-184-billion-for-Goodrich.html',
#    'source_description': 'UTC shells out $18.4 billion for Goodrich',
#    'acquired_year': 2011,
#    'acquired_month': 9,
#    'acquired_day': 22,
#    'acquiring_company': {'name': 'United Technologies',
# ...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(coleccion.find({'founded_year': {"$exists": True}},{"etiqueta":1,"_id":0,"name":1,"founded_year":1}).sort("founded_year", -1))[0:10]
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013},
#  {'name': 'Gimigo', 'founded_year': 2013},
#  {'name': 'SEOGroup', 'founded_year': 2013},
#  {'name': 'Clowdy', 'founded_year': 2013},
#  {'name': 'WhosCall', 'founded_year': 2013},
#  {'name': 'Pikk', 'founded_year': 2013}]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
fdaysap = pd.DataFrame(coleccion.find({'founded_day': {"$lte": 7}}).sort("acquisition.price_amount",-1).limit(10)) 
fdaysap.head(2)
# Out:
#                         _id      name permalink  \
# 0  52cdef7d4bab8bd6752989a1  Netscape  netscape
# 1  52cdef7c4bab8bd675297e89    PayPal    paypal
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/netscape  http://netscape.aol.com
# 1    http://www.crunchbase.com/company/paypal    http://www.paypal.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0                                              software                  NaN
# 1                                  paypal       finance             300000.0
#
#    founded_year  founded_month  founded_day  deadpooled_year  \
# 0          1994              4            4              NaN
# 1          1998             12            1              NaN
#
#    deadpooled_month  deadpooled_day deadpooled_url  \
# 0               NaN             NaN           None
# 1               NaN             NaN           None
#
# ...

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
cond1 = {'category_code': {"$eq": "web"}}
cond2 = {'number_of_employees': {"$gt": 4000}}

webcat = pd.DataFrame(coleccion.find({'$and': [cond1, cond2]}).sort("number_of_employees",1))
webcat.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7c4bab8bd67529822a  Expedia   expedia
# 1  52cdef7c4bab8bd675297e96      AOL       aol
#
#                               crunchbase_url            homepage_url  \
# 0  http://www.crunchbase.com/company/expedia  http://www.expedia.com
# 1      http://www.crunchbase.com/company/aol      http://www.aol.com
#
#                blog_url                                   blog_feed_url  \
# 0
# 1  http://blog.aol.com/  http://feeds.feedburner.com/AolBlog?format=xml
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0          Expedia           web                 4400          1996
# 1              aol           web                 8000          1985
#
#    founded_month  founded_day deadpooled_year deadpooled_month deadpooled_day  \
# 0            NaN          NaN            None             None           None
# 1            5.0         24.0            None             None           None
#
# ...

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond1 = {'acquisition.price_currency_code': {"$eq": "EUR"}}
cond2 = {'acquisition.price_amount': {"$gt": 10000000}}

adq = pd.DataFrame(coleccion.find({'$and': [cond1, cond2]}))
adq.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7c4bab8bd675297f02      ZYB       zyb
# 1  52cdef7d4bab8bd675298bf3  Apertio   apertio
#
#                               crunchbase_url            homepage_url  \
# 0      http://www.crunchbase.com/company/zyb          http://zyb.com
# 1  http://www.crunchbase.com/company/apertio  http://www.apertio.com
#
#                blog_url                        blog_feed_url twitter_username  \
# 0  http://blog.zyb.com/  http://blog.zyb.com/index.php/feed/             None
# 1                                                                        None
#
#   category_code  number_of_employees  founded_year  founded_month  \
# 0        mobile                 25.0           NaN            NaN
# 1        mobile                  NaN           NaN            NaN
#
#    founded_day deadpooled_year deadpooled_month deadpooled_day deadpooled_url  \
# 0          NaN            None             None           None           None
# ...

# %%
cond1 = {'acquisition.price_currency_code': {"$eq": "EUR"}}
cond2 = {'acquisition.price_amount': {"$gt": 10000000}}

list(coleccion.find({'$and': [cond1, cond2]},{"etiqueta":1,"_id":0,"acquisition.price_amount":1,"acquisition.price_currency_code":1}))[0:5]
# Out:
# [{'acquisition': {'price_amount': 31500000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 140000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 40000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'acquisition': {'price_amount': 24000000, 'price_currency_code': 'EUR'}}]

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(coleccion.find({'acquisition.acquired_month': {"$lte": 3}}, {"etiqueta":1,"_id":0,"name":1,"acquisition":1}).limit(10))[0:3]
# Out:
# [{'name': 'Kyte',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/',
#    'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million',
#    'acquired_year': 2011,
#    'acquired_month': 1,
#    'acquired_day': 31,
#    'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}},
#  {'name': 'NetRatings',
#   'acquisition': {'price_amount': 327000000,
#    'price_currency_code': 'USD',
#    'term_code': 'cash',
#    'source_url': 'http://login.vnuemedia.com/hr/login/login_subscribe.jsp?id=0oqDem1gYIfIclz9i2%2Ffqj5NxCp2AC5DPbVnyT2da8GyV2mXjasabE128n69OrmcAh52%2FGE3pSG%2F%0AEKRYD9vh9EhrJrxukmUzh532fSMTZXL42gwPB80UWVtF1NwJ5UZSM%2BCkLU1mpYBoHFgiH%2Fi0f6Ax%0A9yMIVxt47t%2BHamhEQ0nkOEK24L',
#    'source_description': 'Nielsen buys rest of NetRatings',
# ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
cond1 = {'founded_year': {"$gte": 2000}}
cond2 = {'founded_year': {"$lte": 2010}}
cond3 = {'acquisition.acquired_year': {"$exists": False}}
cond4 = {'acquisition.acquired_year': {"$gte": 2011}}


multcond = pd.DataFrame(coleccion.find({'$and': [cond1, cond2,{ "$or" : [ cond3, cond4 ] }]}))
multcond.head(1)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint      abc2
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0  BachelrWetpaint           web                 47.0          2005
#
#    founded_month  founded_day  deadpooled_year  \
# 0           10.0         17.0              1.0
#
#                                             tag_list alias_list  \
# 0  wiki, seattle, elowitz, media-industry, media-...
#
#        email_address  phone_number                  description  \
# 0  info@wetpaint.com  206.859.6300  Technology Platform Company
#
#             created_at                    updated_at  \
# ...

# %%
list(coleccion.find({'$and': [cond1, cond2,{ "$or" : [ cond3, cond4 ] }]},{"etiqueta":1,"_id":0,"founded_year":1,"acquisition.acquired_year":1}))[0:10]
# Out:
# [{'founded_year': 2005, 'acquisition': {'acquired_year': 2013}},
#  {'founded_year': 2005},
#  {'founded_year': 2004, 'acquisition': {'acquired_year': 2012}},
#  {'founded_year': 2004},
#  {'founded_year': 2005},
#  {'founded_year': 2006, 'acquisition': {'acquired_year': 2012}},
#  {'founded_year': 2006},
#  {'founded_year': 2007},
#  {'founded_year': 2006},
#  {'founded_year': 2007}]

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
{
   $dateDiff: {
      startDate: founded_year,
      endDate: deadpooled_year,
      unit: year,

   }
}

#Es con datediff??
