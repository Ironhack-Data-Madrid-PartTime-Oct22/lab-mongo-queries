# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# from pymongo import MongoClient
# client = MongoClient("")
import pymongo
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

# %%
cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
cliente.list_database_names()
# Out:
# ['admin', 'alojamientos', 'companies', 'config', 'local']

# %%
mybd = cliente.get_database("companies")

# %%
coleccion =mybd.companies

# %%
df = pd.read_json("../companies.json", lines = True)

# %%
df.head()
# Out:
#                                     _id       name permalink  \
# 0  {'$oid': '52cdef7c4bab8bd675297d8a'}   Wetpaint      abc2
# 1  {'$oid': '52cdef7c4bab8bd675297d8b'}  AdventNet      abc3
# 2  {'$oid': '52cdef7c4bab8bd675297d8c'}       Zoho      abc4
# 3  {'$oid': '52cdef7c4bab8bd675297d8d'}       Digg      digg
# 4  {'$oid': '52cdef7c4bab8bd675297d8e'}   Facebook  facebook
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
# 3       http://www.crunchbase.com/company/digg      http://www.digg.com
# 4   http://www.crunchbase.com/company/facebook      http://facebook.com
#
#                       blog_url                      blog_feed_url  \
# 0  http://digitalquarters.net/   http://digitalquarters.net/feed/
# 1
# ...

# %%
df.columns
# Out:
# Index(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url',
#        'blog_url', 'blog_feed_url', 'twitter_username', 'category_code',
#        'number_of_employees', 'founded_year', 'founded_month', 'founded_day',
#        'deadpooled_year', 'tag_list', 'alias_list', 'email_address',
#        'phone_number', 'description', 'created_at', 'updated_at', 'overview',
#        'image', 'products', 'relationships', 'competitions', 'providerships',
#        'total_money_raised', 'funding_rounds', 'investments', 'acquisition',
#        'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots',
#        'external_links', 'partners', 'deadpooled_month', 'deadpooled_day',
#        'deadpooled_url', 'ipo'],
#       dtype='object')

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
q1 = pd.DataFrame(list(coleccion.find({"name" : "Babelgum"})))
q1
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297da0  Babelgum  babelgum
#
#                                crunchbase_url         homepage_url  \
# 0  http://www.crunchbase.com/company/babelgum  http://babelgum.com
#
#                    blog_url                         blog_feed_url  \
# 0  http://babelgum.com/blog  http://feeds.feedburner.com/Babelgum
#
#   twitter_username category_code number_of_employees  ...  investments  \
# 0         Babelgum   games_video                None  ...           []
#
#    acquisition  acquisitions  \
# 0         None            []
#
#                                              offices  milestones   ipo  \
# 0  [{'description': '', 'address1': '', 'address2...          []  None
#
#   video_embeds screenshots external_links partners
# 0           []          []             []       []
#
# [1 rows x 42 columns]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
q2 = pd.DataFrame(list(coleccion.find({'number_of_employees':{'$gt': 5000}}))[:20])
q2.name.unique()
# Out:
# array(['Facebook', 'eBay', 'Cisco', 'Yahoo!', 'Google', 'Intel',
#        'Nintendo', 'Adobe Systems', 'Sony', 'PayPal',
#        'The Walt Disney Company', 'AOL', 'Webkinz', 'Sun Microsystems',
#        'Nokia', 'Rakuten', 'Microsoft', 'Apple', 'NetApp',
#        'Motorola Solutions'], dtype=object)

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
cond1 = {"founded_year":{"$gte": 2000}}
cond2 = {"founded_year":{"$lte": 2005}}
q3 = pd.DataFrame(list(coleccion.find({"$and":[cond1, cond2]}, {"name":1,"founded_year":1,"_id":0})))
q3.head()
# Out:
#         name  founded_year
# 0   Wetpaint          2005
# 1       Zoho          2005
# 2       Digg          2004
# 3   Facebook          2004
# 4  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond3 = {"founded_year":{"$lt": 2010}}
cond4 = {"ipo.valuation_amount":{"$gt": 100000000}}
q4 = pd.DataFrame(list(coleccion.find({"$and":[cond3, cond4]}, {"name":1,"ipo":1,"_id":0})))
q4.head()
# Out:
#        name                                                ipo
# 0  Facebook  {'valuation_amount': 104000000000, 'valuation_...
# 1   Twitter  {'valuation_amount': 18100000000, 'valuation_c...
# 2      Yelp  {'valuation_amount': 1300000000, 'valuation_cu...
# 3  LinkedIn  {'valuation_amount': 9310000000, 'valuation_cu...
# 4    Amazon  {'valuation_amount': 100000000000, 'valuation_...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond5 = {"founded_year":{"$lt": 2005}}
cond6 = {{'number_of_employees':{'$lt': 1000}}
q5 = pd.DataFrame(list(coleccion.find({"$and":[cond5, cond6]}, {"name":1,"_id":0}))[:10])
q5.head()
# Out:
#   Cell In [49], line 3
#     q5 = pd.DataFrame(list(coleccion.find({"$and":[cond5, cond6]}, {"name":1,"_id":0}))[:10])
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
q6 = pd.DataFrame(list(coleccion.find({"partners": {'$exists': False}}, {"name":1,"_id":0})))
q6.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
q7= pd.DataFrame(list(coleccion.find({"category_code":{"$type":"null"}}, {"name":1,"_id":0})))
q7.head()
# Out:
#            name
# 0    Collective
# 1       Snimmer
# 2        KoolIM
# 3  Level9 Media
# 4       VidKing

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond8 = {'number_of_employees':{'$gte': 100}} 
cond7 = {'number_of_employees':{'$lt': 1000}}
         
q8 = pd.DataFrame(list(coleccion.find({"$and":[cond7, cond8]}, {"name":1,"_id":0})))
q8.head()
# Out:
#         name
# 0  AdventNet
# 1    AddThis
# 2      OpenX
# 3   LifeLock
# 4      Jajah

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
q9= pd.DataFrame(list(coleccion.find().sort("ipo", -1)))

# %%
q9.head(10)
# Out:
#                         _id             name        permalink  \
# 0  52cdef7e4bab8bd67529a8b4             GREE             gree
# 1  52cdef7c4bab8bd675297d8e         Facebook         facebook
# 2  52cdef7c4bab8bd675297e7a           Amazon           amazon
# 3  52cdef7c4bab8bd675297d94          Twitter          twitter
# 4  52cdef7d4bab8bd675299d5d          Groupon          groupon
# 5  52cdef7c4bab8bd675298674          Tencent          tencent
# 6  52cdef7e4bab8bd67529b996  Western Digital  western-digital
# 7  52cdef7c4bab8bd675297e0c         LinkedIn         linkedin
# 8  52cdef7c4bab8bd67529859a     BMC Software     bmc-software
# 9  52cdef7c4bab8bd675298527        Rackspace        rackspace
#
#                                       crunchbase_url  \
# 0             http://www.crunchbase.com/company/gree
# 1         http://www.crunchbase.com/company/facebook
# 2           http://www.crunchbase.com/company/amazon
# 3          http://www.crunchbase.com/company/twitter
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
q10= pd.DataFrame(list(coleccion.find().sort("number_of_employees", -1))[:10])

# %%
q10
# Out:
#                         _id                                        name  \
# 0  52cdef7d4bab8bd67529941a                                     Siemens
# 1  52cdef7c4bab8bd67529856a                                         IBM
# 2  52cdef7d4bab8bd675299d33                                      Toyota
# 3  52cdef7c4bab8bd675297e89                                      PayPal
# 4  52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5  52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6  52cdef7d4bab8bd675298b99                                   Accenture
# 7  52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8  52cdef7e4bab8bd67529aa51                   Flextronics International
# 9  52cdef7d4bab8bd675299156                                     Safeway
#
#                                     permalink  \
# 0                                     siemens
# 1                                         ibm
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
cond9 ={"founded_month":{"$gt": 6}}
q11= pd.DataFrame(list(coleccion.find({"$and":[cond9]},{"name":1,"_id":0}))[:1000])

# %%
q11.head()
# Out:
#         name
# 0   Wetpaint
# 1       Zoho
# 2       Digg
# 3  Omnidrive
# 4       eBay

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
df.columns
# Out:
# Index(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url',
#        'blog_url', 'blog_feed_url', 'twitter_username', 'category_code',
#        'number_of_employees', 'founded_year', 'founded_month', 'founded_day',
#        'deadpooled_year', 'tag_list', 'alias_list', 'email_address',
#        'phone_number', 'description', 'created_at', 'updated_at', 'overview',
#        'image', 'products', 'relationships', 'competitions', 'providerships',
#        'total_money_raised', 'funding_rounds', 'investments', 'acquisition',
#        'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots',
#        'external_links', 'partners', 'deadpooled_month', 'deadpooled_day',
#        'deadpooled_url', 'ipo'],
#       dtype='object')

# %%
cond10 = {"founded_year":{"$lt": 2000}}
cond11 = {"acquisition.price_amount": {"$gt": 1000000}}
q12= pd.DataFrame(list(coleccion.find({"$and":[cond10, cond11]},{"name":1,"_id":0})))

# %%
q12.head()
# Out:
#          name
# 0     Postini
# 1    SideStep
# 2  Recipezaar
# 3     Cyworld
# 4      PayPal

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
q13 = pd.DataFrame(list(coleccion.find({"acquisition.acquired_year":{"$gt":2010}},
               {"name":1,"acquisition.price_amount":1,"_id":0}).sort("acquisition.price_amount",-1)))

# %%
q13.head()
# Out:
#                      name                    acquisition
# 0                T-Mobile  {'price_amount': 39000000000}
# 1    Goodrich Corporation  {'price_amount': 18400000000}
# 2                     LSI   {'price_amount': 6600000000}
# 3  National Semiconductor   {'price_amount': 6500000000}
# 4                   Ariba   {'price_amount': 4300000000}

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
q14 = pd.DataFrame(list(coleccion.find((),{"name":1,"founded_year":1,"_id":0}).sort("founded_year", -1)))
q14.head()
# Out:
#         name  founded_year
# 0      Fixya        2013.0
# 1      Wamba        2013.0
# 2  Advaliant        2013.0
# 3       Fluc        2013.0
# 4     iBazar        2013.0

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
q15 = pd.DataFrame(list(coleccion
                        .find({"founded_day":{"$lte":7}},
                        {"name":1,"acquisition.price_amount":1,"_id":0})
                          .sort("acquisition.price_amount",-1))[:10])

# %%
q15
# Out:
#                 name                   acquisition
# 0           Netscape  {'price_amount': 4200000000}
# 1             PayPal  {'price_amount': 1500000000}
# 2             Zappos  {'price_amount': 1200000000}
# 3            Alibaba  {'price_amount': 1000000000}
# 4            Postini   {'price_amount': 625000000}
# 5             Danger   {'price_amount': 500000000}
# 6  Clearwell Systems   {'price_amount': 410000000}
# 7         PrimeSense   {'price_amount': 345000000}
# 8             Amobee   {'price_amount': 321000000}
# 9        BlueLithium   {'price_amount': 300000000}

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
cond12 = {"number_of_employees":{"$gt":4000}}
cond13 = {"category_code":"web"}
q16 = pd.DataFrame(list(coleccion.find({"$and":[cond9,cond10]},
                                     {"name":1,"_id":0}).sort("number_of_employees",-1)))

# %%
q16.head()
# Out:
#                       name
# 0                   PayPal
# 1               ExxonMobil
# 2                   Google
# 3              kalimatapla
# 4  The Walt Disney Company

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond14 = {"acquisition.price_amount":{"$gt":10000000}}
cond15 = {"acquisition.price_currency_code":"EUR"}
q17 = pd.DataFrame(list(coleccion.find({"$and":[cond11,cond12]},{"name":1,"_id":0})))
q17
# Out:
#                            name
# 0                        PayPal
# 1              Sun Microsystems
# 2                           LSI
# 3                        VMware
# 4                         Xerox
# 5                        Novell
# 6  Affiliated Computer Services

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
q18 = pd.DataFrame(list(coleccion.find(({"acquisition.acquired_month":{"$lte":3}}),{"name":1,"acquisition":1,"_id":0}))[:10])
q18
# Out:
#           name                                        acquisition
# 0         Kyte  {'price_amount': None, 'price_currency_code': ...
# 1   NetRatings  {'price_amount': 327000000, 'price_currency_co...
# 2       blogTV  {'price_amount': None, 'price_currency_code': ...
# 3   Livestream  {'price_amount': None, 'price_currency_code': ...
# 4     iContact  {'price_amount': 169000000, 'price_currency_co...
# 5      Coghead  {'price_amount': None, 'price_currency_code': ...
# 6  Dailymotion  {'price_amount': 168000000, 'price_currency_co...
# 7     Netvibes  {'price_amount': None, 'price_currency_code': ...
# 8       Flickr  {'price_amount': None, 'price_currency_code': ...
# 9   BabyCenter  {'price_amount': None, 'price_currency_code': ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code
